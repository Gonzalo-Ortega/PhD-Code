# %%
from src.my_algorithms import *
import importlib
importlib.reload(src.my_algorithms)
# Out:
# <module 'src.my_algorithms' from '/home/gonzalo/PhD-Code/my-phd-code/src/my_algorithms.py'>

# %%
points = np.random.uniform(low=0, high=1, size=(10, 2))
#print(points)
#plot_points(points, 2)
# Out:
# [[0.29439568 0.07397784]
#  [0.91625541 0.41476612]
#  [0.18025656 0.30982593]
#  [0.52567002 0.95676015]
#  [0.51347785 0.33585956]
#  [0.07787884 0.53197679]
#  [0.14543029 0.00592489]
#  [0.28532371 0.91157179]
#  [0.87641154 0.05886895]
#  [0.37442078 0.73890645]]
# numpy.ndarray
